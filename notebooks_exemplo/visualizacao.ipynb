# %% [markdown]
# # Importação das bibliotecas

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
base_original = pd.read_parquet('../data/processed/base_casa_v2.parquet')
base_original
# Out:
#       tipo_imovel                                     nome     preco metragem  \
# 0     Apartamento  Apartamento com 2 Quartos à Venda, 65m²  310000.0       65
# 2     Apartamento  Apartamento com 2 Quartos à Venda, 71m²  403500.0       71
# 3     Apartamento  Apartamento com 2 Quartos à Venda, 54m²  290000.0       54
# 4     Apartamento  Apartamento com 2 Quartos à Venda, 45m²  166420.0       45
# 5     Apartamento  Apartamento com 2 Quartos à Venda, 64m²  370000.0       64
# ...           ...                                      ...       ...      ...
# 9946         Casa        Casa com 3 Quartos à Venda, 144m²  399000.0      144
# 9947         Casa        Casa com 3 Quartos à Venda, 100m²  265000.0      100
# 9948         Casa         Casa com 2 Quartos à Venda, 81m²  185000.0       81
# 9949         Casa        Casa com 3 Quartos à Venda, 222m²  430000.0      222
# 9950         Casa        Casa com 4 Quartos à Venda, 160m²  595000.0      160
#
#      quarto banheiro garagem     ID_CASA  \
# 0        2        2       1   2699716579
# 2        2        2       2   2690493538
# 3        2        2       1   2667652105
# 4        2        1       1   2682840782
# 5        2        2       2   2688027260
# ...     ...      ...     ...         ...
# 9946     3        2       4   2622227362
# 9947     3        2       4   2672360578
# 9948     2        1       1   2615919718
# 9949     3        2       2   2631657528
# 9950     4        4       2   2635510468
#
#                                     bairro_teste
# 0                                Jardim Botânico
# 2                                Bonfim Paulista
# 3                                   Nova Aliança
# 4     Conjunto Habitacional Jardim Das Palmeiras
# 5                                 Vila Ana Maria
# ...                                          ...
# 9946        Parque Residencial Cândido Portinari
# 9947                    Dom Bernardo Jose Mielle
# 9948                     Jardim Maria Das Graças
# 9949                       Parque Ribeirão Preto
# 9950                           Jardim Califórnia
#
# [15390 rows x 9 columns]

# %%
base_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15390 entries, 0 to 9950
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tipo_imovel   15390 non-null  string
#  1   nome          15390 non-null  string
#  2   preco         15390 non-null  float64
#  3   metragem      15390 non-null  string
#  4   quarto        15390 non-null  string
#  5   banheiro      15390 non-null  string
#  6   garagem       15390 non-null  string
#  7   ID_CASA       15390 non-null  int64
#  8   bairro_teste  15390 non-null  string
# dtypes: float64(1), int64(1), string(7)
# memory usage: 1.2 MB

# %% [markdown]
# - Total de tipos de imóvel Geral

# %%
base_bairro = base_original['tipo_imovel']
base_bairro_valor_bruto = base_bairro.value_counts() 
base_bairro_valor_bruto
# Out:
# tipo_imovel
# Apartamento    8395
# Casa           6995
# Name: count, dtype: Int64

# %%
base_bairro_percentual = base_original['tipo_imovel']
base_bairro_percentual = round(base_bairro.value_counts(normalize=True) * 100, 2)
base_bairro_percentual
# Out:
# tipo_imovel
# Apartamento    54.55
# Casa           45.45
# Name: proportion, dtype: Float64

# %%
base_bairro_completa = pd.DataFrame({'FREQ': base_bairro_valor_bruto, 'PCT': base_bairro_percentual})
base_bairro_completa.reset_index()
# Out:
#    tipo_imovel  FREQ    PCT
# 0  Apartamento  8395  54.55
# 1         Casa  6995  45.45

# %% [markdown]
# - Total de tipos de imóvel bairro

# %%
bairro = 'Sumarezinho'

base_bairro_valor = base_original.query(f'bairro_teste == "{bairro}"')['tipo_imovel']
base_bairro_valor = base_bairro_valor.value_counts()
base_bairro_valor
# Out:
# tipo_imovel
# Casa           147
# Apartamento    118
# Name: count, dtype: Int64

# %%
bairro = 'Sumarezinho'

base_bairro_pct = base_original.query(f'bairro_teste == "{bairro}"')['tipo_imovel']
base_bairro_pct = round(base_bairro_pct.value_counts(normalize=True), 2) * 100
base_bairro_pct
# Out:
# tipo_imovel
# Casa           55.0
# Apartamento    45.0
# Name: proportion, dtype: Float64

# %%
base_bairro_filtrada = pd.DataFrame({'FREQ': base_bairro_valor, 'PCT': base_bairro_pct })
base_bairro_filtrada = base_bairro_filtrada.reset_index()
base_bairro_filtrada
# Out:
#    tipo_imovel  FREQ   PCT
# 0         Casa   147  55.0
# 1  Apartamento   118  45.0

# %% [markdown]
# 2. **Preço:**
#    - Estatísticas descritivas básicas (média, mediana, mínimo, máximo, desvio padrão).

# %%
coluna_analise = 'metragem'

# %%
media = base_original[coluna_analise].mean()
mediana = base_original[coluna_analise].median()
minimo = base_original[coluna_analise].min()
maximo = base_original[coluna_analise].max()
moda = base_original[coluna_analise].mode()[0]
dp = base_original[coluna_analise].std()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 media = base_original[coluna_analise].mean()
#       2 mediana = base_original[coluna_analise].median()
#       3 minimo = base_original[coluna_analise].min()
#
# File ~/Documentos/projetos/extracao_viva_real_selenium/venv/lib/python3.11/site-packages/pandas/core/series.py:6540, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/Documentos/projetos/extracao_viva_real_selenium/venv/lib/python3.11/site-packages/pandas/core/generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
#   12418         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12419     )
#
# File ~/Documentos/projetos/extracao_viva_real_selenium/venv/lib/python3.11/site-packages/pandas/core/generic.py:12374, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12370 nv.validate_func(name, (), kwargs)
#   12372 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12374 return self._reduce(
#   12375     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376 )
#
# File ~/Documentos/projetos/extracao_viva_real_selenium/venv/lib/python3.11/site-packages/pandas/core/series.py:6434, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6430     self._get_axis_number(axis)
#    6432 if isinstance(delegate, ExtensionArray):
#    6433     # dispatch to ExtensionArray interface
# -> 6434     return delegate._reduce(name, skipna=skipna, **kwds)
#    6436 else:
#    6437     # dispatch to numpy arrays
#    6438     if numeric_only and self.dtype.kind not in "iufcb":
#    6439         # i.e. not is_numeric_dtype(self.dtype)
#
# File ~/Documentos/projetos/extracao_viva_real_selenium/venv/lib/python3.11/site-packages/pandas/core/arrays/string_.py:523, in StringArray._reduce(self, name, skipna, axis, **kwargs)
#     520 if name in ["min", "max"]:
#     521     return getattr(self, name)(skipna=skipna, axis=axis)
# --> 523 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype

# %%
maximo = base_original.shape[0] // 3
maximo
# Out:
# 5130

# %%
fig = px.histogram(
    base_original,
    x='preco',
    nbins=50

)

fig.update_layout(bargap=0.1) 
fig.show()

# %% [markdown]
# - bairro

# %%
base_original['bairro_teste'].unique()
# Out:
# <StringArray>
# [                           'Jardim Botânico',
#                             'Bonfim Paulista',
#                                'Nova Aliança',
#  'Conjunto Habitacional Jardim Das Palmeiras',
#                              'Vila Ana Maria',
#                            'Jardim Republica',
#                                    'Lagoinha',
#                               'Jardim Sumare',
#                     'Parque Dos Bandeirantes',
#                                    'Ipiranga',
#  ...
#                            'Jardim Aeroporto',
#                  'Jardim Mario Paiva Arantes',
#                       'Condomínio Buona Vita',
#                                 'Vila Hipica',
#                             'Jardim Procopio',
#                   'Jardim Dona Branca Salles',
#                       'Condominio San Remo I',
#              'Condominio Reserva Santa Luisa',
#                           'Reserva Sant Anna',
#             'Condominio Parque Das Figueiras']
# Length: 253, dtype: string

# %%
bairro = 'Lagoinha'
tipo_imovel = 'Apartamento'

base_original_bairro = base_original.query(f'bairro_teste == "{bairro}" and tipo_imovel == "{tipo_imovel}"')
base_original_bairro
# Out:
#       tipo_imovel                                      nome     preco  \
# 7     Apartamento   Apartamento com 2 Quartos à Venda, 69m²  259000.0
# 62    Apartamento   Apartamento com 2 Quartos à Venda, 49m²  235000.0
# 168   Apartamento   Apartamento com 2 Quartos à Venda, 47m²  210000.0
# 188   Apartamento   Apartamento com 2 Quartos à Venda, 67m²  237000.0
# 189   Apartamento   Apartamento com 2 Quartos à Venda, 84m²  330000.0
# ...           ...                                       ...       ...
# 9429  Apartamento  Apartamento com 3 Quartos à Venda, 115m²  430000.0
# 9687  Apartamento   Apartamento com 3 Quartos à Venda, 65m²  250000.0
# 9714  Apartamento   Apartamento com 2 Quartos à Venda, 74m²  315000.0
# 9948  Apartamento   Apartamento com 2 Quartos à Venda, 48m²  170000.0
# 9970  Apartamento   Apartamento com 2 Quartos à Venda, 48m²  175000.0
#
#      metragem quarto banheiro garagem     ID_CASA bairro_teste
# 7          69     2        2       2   2697835178     Lagoinha
# 62         49     2        2       1   2688829214     Lagoinha
# 168        47     2        1       1   2671614914     Lagoinha
# 188        67     2        2       1   2617732339     Lagoinha
# 189        84     2        2       1   2662546346     Lagoinha
# ...       ...    ...      ...     ...         ...          ...
# 9429      115     3        2       2     78718602     Lagoinha
# 9687       65     3        2       1   2648129893     Lagoinha
# 9714       74     2        2       1   2435752044     Lagoinha
# 9948       48     2        1       1   2697659574     Lagoinha
# 9970       48     2        1       1   2572455642     Lagoinha
#
# [88 rows x 9 columns]

# %%
media = base_original_bairro['preco'].mean()
mediana = base_original_bairro['preco'].median()
minimo = base_original_bairro['preco'].min()
maximo = base_original_bairro['preco'].max()
moda = base_original_bairro['preco'].mode()[0]
dp = base_original_bairro['preco'].std()

# %%
fig = px.histogram(
    base_original_bairro,
    x='preco',
    nbins=50

)

fig.update_layout(bargap=0.1) 
fig.show()

# %%
base_original_bairro[['preco', 'metragem']].corr()
# Out:
#              preco  metragem
# preco     1.000000  0.632056
# metragem  0.632056  1.000000

# %%
fig = px.histogram(base_original_bairro, x='preco', nbins=30)
fig.update_layout(bargap=0.1) 
fig.show()

# %%
fig = px.box(base_original_bairro,  y='preco')
fig.show()
